# %% [markdown]
# # preprocessing

# %%
import pandas as pd
import re
import string
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv("/content/drive/My Drive/Colab-Notebooks/Analisis-Sentimen-Twitter-Terhadap-Pembatalan-Piala-Dunia-U-20-di-Indonesia-Tahun-2023-main/Dataset/nikuba2-label.csv", encoding='utf-8')
df
# Out:
#                                                   Text    Label
# 0    SAYA SIAP ANGGARKAN RP 40.000 TRILIUN UNTUK NI...  positif
# 1    tolong pemerintah perhatianya ke nikuba,kayany...  positif
# 2    Kalau nikuba,di pakai di Indonesia, tidak ada ...  negatif
# 3    Kalau nikuba,di pakai di Indonesia, tidak ada ...  negatif
# 4    Kalau alat nikuba ini di kembangkan, Pertamina...   netral
# ..                                                 ...      ...
# 549  NIKUBA menyelamatkan kendaraan bensin dari ken...   netral
# 550  15 milyar terlalu kecil, NIKUBA bernilai 1000r...  negatif
# 551  Mengapa pemerintah tidak mau menerima hasil ka...  negatif
# 552  Seharusnya Metro TV tidak hanya nanya ke Aryan...  positif
# 553  Ah, cuma diundang buat presentasi di eropa doa...  positif
#
# [554 rows x 2 columns]

# %% [markdown]
# # Case folding

# %%
#Case Folding
df['CaseFolding'] = df['Text'].str.lower()
df.head()
# Out:
#                                                 Text    Label  \
# 0  SAYA SIAP ANGGARKAN RP 40.000 TRILIUN UNTUK NI...  positif
# 1  tolong pemerintah perhatianya ke nikuba,kayany...  positif
# 2  Kalau nikuba,di pakai di Indonesia, tidak ada ...  negatif
# 3  Kalau nikuba,di pakai di Indonesia, tidak ada ...  negatif
# 4  Kalau alat nikuba ini di kembangkan, Pertamina...   netral
#
#                                          CaseFolding
# 0  saya siap anggarkan rp 40.000 triliun untuk ni...
# 1  tolong pemerintah perhatianya ke nikuba,kayany...
# 2  kalau nikuba,di pakai di indonesia, tidak ada ...
# 3  kalau nikuba,di pakai di indonesia, tidak ada ...
# 4  kalau alat nikuba ini di kembangkan, pertamina...

# %% [markdown]
# # Celaning Data

# %%
# ------ CleanData ---------

def remove_tweet_special(text):

    #menghapus username twitter
    text = re.sub('@[^\s]+','',text)

    # remove tab, new line, ans back slice
    text = text.replace('\\t'," ").replace('\\n'," ").replace('\\u'," ").replace('\\',"")

    # remove non ASCII (emoticon, chinese word, .etc)
    text = text.encode('ascii', 'replace').decode('ascii')

    # remove mention, link, hashtag
    text = ' '.join(re.sub("([@#][A-Za-z0-9]+)|(\w+:\/\/\S+)"," ", text).split())

    #remove number
    text = re.sub(r"\d+", "", text)

    #remove punctuation
    text = text.translate(str.maketrans("","",string.punctuation))

    # remove white space
    text = text.strip()

    #remove multiple white space
    text = re.sub('\s+',' ',text)

    #remove single char
    text = re.sub(r"\b[a-zA-Z]\b", "", text)

    # remove incomplete URL
    return text.replace("http://", " ").replace("https://", " ")


df['TextClean'] = df['CaseFolding'].apply(remove_tweet_special)

# %%
df
# Out:
#                                                   Text    Label  \
# 0    SAYA SIAP ANGGARKAN RP 40.000 TRILIUN UNTUK NI...  positif
# 1    tolong pemerintah perhatianya ke nikuba,kayany...  positif
# 2    Kalau nikuba,di pakai di Indonesia, tidak ada ...  negatif
# 3    Kalau nikuba,di pakai di Indonesia, tidak ada ...  negatif
# 4    Kalau alat nikuba ini di kembangkan, Pertamina...   netral
# ..                                                 ...      ...
# 549  NIKUBA menyelamatkan kendaraan bensin dari ken...   netral
# 550  15 milyar terlalu kecil, NIKUBA bernilai 1000r...  negatif
# 551  Mengapa pemerintah tidak mau menerima hasil ka...  negatif
# 552  Seharusnya Metro TV tidak hanya nanya ke Aryan...  positif
# 553  Ah, cuma diundang buat presentasi di eropa doa...  positif
#
#                                            CaseFolding  \
# 0    saya siap anggarkan rp 40.000 triliun untuk ni...
# 1    tolong pemerintah perhatianya ke nikuba,kayany...
# 2    kalau nikuba,di pakai di indonesia, tidak ada ...
# 3    kalau nikuba,di pakai di indonesia, tidak ada ...
# 4    kalau alat nikuba ini di kembangkan, pertamina...
# ..                                                 ...
# 549  nikuba menyelamatkan kendaraan bensin dari ken...
# 550  15 milyar terlalu kecil, nikuba bernilai 1000r...
# 551  mengapa pemerintah tidak mau menerima hasil ka...
# 552  seharusnya metro tv tidak hanya nanya ke aryan...
# 553  ah, cuma diundang buat presentasi di eropa doa...
#
#                                              TextClean
# 0    saya siap anggarkan rp triliun untuk nikuba ka...
# 1    tolong pemerintah perhatianya ke nikubakayanya...
# 2    kalau nikubadi pakai di indonesia tidak ada la...
# 3    kalau nikubadi pakai di indonesia tidak ada la...
# 4    kalau alat nikuba ini di kembangkan pertamina ...
# ..                                                 ...
# 549  nikuba menyelamatkan kendaraan bensin dari ken...
# 550  milyar terlalu kecil nikuba bernilai ribuan tr...
# 551  mengapa pemerintah tidak mau menerima hasil ka...
# 552  seharusnya metro tv tidak hanya nanya ke aryan...
# 553  ah cuma diundang buat presentasi di eropa doan...
#
# [554 rows x 4 columns]

# %% [markdown]
# ## Tokenizing

# %%
# Tokenzing
# NLTK word rokenize
def word_tokenize_wrapper(text):
    return word_tokenize(text)
df['tokens'] =df['TextClean'].apply(word_tokenize_wrapper)
df
# Out:
#                                                   Text    Label  \
# 0    SAYA SIAP ANGGARKAN RP 40.000 TRILIUN UNTUK NI...  positif
# 1    tolong pemerintah perhatianya ke nikuba,kayany...  positif
# 2    Kalau nikuba,di pakai di Indonesia, tidak ada ...  negatif
# 3    Kalau nikuba,di pakai di Indonesia, tidak ada ...  negatif
# 4    Kalau alat nikuba ini di kembangkan, Pertamina...   netral
# ..                                                 ...      ...
# 549  NIKUBA menyelamatkan kendaraan bensin dari ken...   netral
# 550  15 milyar terlalu kecil, NIKUBA bernilai 1000r...  negatif
# 551  Mengapa pemerintah tidak mau menerima hasil ka...  negatif
# 552  Seharusnya Metro TV tidak hanya nanya ke Aryan...  positif
# 553  Ah, cuma diundang buat presentasi di eropa doa...  positif
#
#                                            CaseFolding  \
# 0    saya siap anggarkan rp 40.000 triliun untuk ni...
# 1    tolong pemerintah perhatianya ke nikuba,kayany...
# 2    kalau nikuba,di pakai di indonesia, tidak ada ...
# 3    kalau nikuba,di pakai di indonesia, tidak ada ...
# 4    kalau alat nikuba ini di kembangkan, pertamina...
# ..                                                 ...
# 549  nikuba menyelamatkan kendaraan bensin dari ken...
# 550  15 milyar terlalu kecil, nikuba bernilai 1000r...
# 551  mengapa pemerintah tidak mau menerima hasil ka...
# 552  seharusnya metro tv tidak hanya nanya ke aryan...
# 553  ah, cuma diundang buat presentasi di eropa doa...
#
#                                              TextClean  \
# 0    saya siap anggarkan rp triliun untuk nikuba ka...
# 1    tolong pemerintah perhatianya ke nikubakayanya...
# 2    kalau nikubadi pakai di indonesia tidak ada la...
# 3    kalau nikubadi pakai di indonesia tidak ada la...
# 4    kalau alat nikuba ini di kembangkan pertamina ...
# ..                                                 ...
# 549  nikuba menyelamatkan kendaraan bensin dari ken...
# 550  milyar terlalu kecil nikuba bernilai ribuan tr...
# 551  mengapa pemerintah tidak mau menerima hasil ka...
# 552  seharusnya metro tv tidak hanya nanya ke aryan...
# 553  ah cuma diundang buat presentasi di eropa doan...
#
#                                                 tokens
# 0    [saya, siap, anggarkan, rp, triliun, untuk, ni...
# 1    [tolong, pemerintah, perhatianya, ke, nikubaka...
# 2    [kalau, nikubadi, pakai, di, indonesia, tidak,...
# 3    [kalau, nikubadi, pakai, di, indonesia, tidak,...
# 4    [kalau, alat, nikuba, ini, di, kembangkan, per...
# ..                                                 ...
# 549  [nikuba, menyelamatkan, kendaraan, bensin, dar...
# 550  [milyar, terlalu, kecil, nikuba, bernilai, rib...
# 551  [mengapa, pemerintah, tidak, mau, menerima, ha...
# 552  [seharusnya, metro, tv, tidak, hanya, nanya, k...
# 553  [ah, cuma, diundang, buat, presentasi, di, ero...
#
# [554 rows x 5 columns]

# %% [markdown]
# ## Normalisasi

# %%
#normalisasi

normalizad_word = pd.read_csv("/content/drive/My Drive/Colab-Notebooks/Analisis-Sentimen-Twitter-Terhadap-Pembatalan-Piala-Dunia-U-20-di-Indonesia-Tahun-2023-main/normalisasi.csv")

normalizad_word_dict = {}

for index, row in normalizad_word.iterrows():
    if row[0] not in normalizad_word_dict:
        normalizad_word_dict[row[0]] = row[1]

def normalized_term(document):
    return [normalizad_word_dict[term] if term in normalizad_word_dict else term for term in document]

df['normalisasi'] = df['tokens'].apply(normalized_term)

df
# Out:
#                                                   Text    Label  \
# 0    SAYA SIAP ANGGARKAN RP 40.000 TRILIUN UNTUK NI...  positif
# 1    tolong pemerintah perhatianya ke nikuba,kayany...  positif
# 2    Kalau nikuba,di pakai di Indonesia, tidak ada ...  negatif
# 3    Kalau nikuba,di pakai di Indonesia, tidak ada ...  negatif
# 4    Kalau alat nikuba ini di kembangkan, Pertamina...   netral
# ..                                                 ...      ...
# 549  NIKUBA menyelamatkan kendaraan bensin dari ken...   netral
# 550  15 milyar terlalu kecil, NIKUBA bernilai 1000r...  negatif
# 551  Mengapa pemerintah tidak mau menerima hasil ka...  negatif
# 552  Seharusnya Metro TV tidak hanya nanya ke Aryan...  positif
# 553  Ah, cuma diundang buat presentasi di eropa doa...  positif
#
#                                            CaseFolding  \
# 0    saya siap anggarkan rp 40.000 triliun untuk ni...
# 1    tolong pemerintah perhatianya ke nikuba,kayany...
# 2    kalau nikuba,di pakai di indonesia, tidak ada ...
# 3    kalau nikuba,di pakai di indonesia, tidak ada ...
# 4    kalau alat nikuba ini di kembangkan, pertamina...
# ..                                                 ...
# 549  nikuba menyelamatkan kendaraan bensin dari ken...
# 550  15 milyar terlalu kecil, nikuba bernilai 1000r...
# 551  mengapa pemerintah tidak mau menerima hasil ka...
# 552  seharusnya metro tv tidak hanya nanya ke aryan...
# 553  ah, cuma diundang buat presentasi di eropa doa...
#
#                                              TextClean  \
# 0    saya siap anggarkan rp triliun untuk nikuba ka...
# 1    tolong pemerintah perhatianya ke nikubakayanya...
# 2    kalau nikubadi pakai di indonesia tidak ada la...
# 3    kalau nikubadi pakai di indonesia tidak ada la...
# 4    kalau alat nikuba ini di kembangkan pertamina ...
# ..                                                 ...
# 549  nikuba menyelamatkan kendaraan bensin dari ken...
# 550  milyar terlalu kecil nikuba bernilai ribuan tr...
# 551  mengapa pemerintah tidak mau menerima hasil ka...
# 552  seharusnya metro tv tidak hanya nanya ke aryan...
# 553  ah cuma diundang buat presentasi di eropa doan...
#
#                                                 tokens  \
# 0    [saya, siap, anggarkan, rp, triliun, untuk, ni...
# 1    [tolong, pemerintah, perhatianya, ke, nikubaka...
# 2    [kalau, nikubadi, pakai, di, indonesia, tidak,...
# 3    [kalau, nikubadi, pakai, di, indonesia, tidak,...
# 4    [kalau, alat, nikuba, ini, di, kembangkan, per...
# ..                                                 ...
# 549  [nikuba, menyelamatkan, kendaraan, bensin, dar...
# 550  [milyar, terlalu, kecil, nikuba, bernilai, rib...
# 551  [mengapa, pemerintah, tidak, mau, menerima, ha...
# 552  [seharusnya, metro, tv, tidak, hanya, nanya, k...
# 553  [ah, cuma, diundang, buat, presentasi, di, ero...
#
#                                            normalisasi
# 0    [saya, siap, anggarkan, rp, triliun, untuk, ni...
# 1    [tolong, pemerintah, perhatianya, ke, nikubaka...
# 2    [kalau, nikubadi, pakai, di, indonesia, tidak,...
# 3    [kalau, nikubadi, pakai, di, indonesia, tidak,...
# 4    [kalau, alat, nikuba, ini, di, kembangkan, per...
# ..                                                 ...
# 549  [nikuba, menyelamatkan, kendaraan, bensin, dar...
# 550  [milyar, terlalu, kecil, nikuba, bernilai, rib...
# 551  [mengapa, pemerintah, tidak, mau, menerima, ha...
# 552  [seharusnya, metro, tv, tidak, hanya, tanya, k...
# 553  [ah, cuma, diundang, buat, presentasi, di, ero...
#
# [554 rows x 6 columns]

# %% [markdown]
# ## StwopWord

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
# ----------------------- get stopword from NLTK stopword -------------------------------
# get stopword indonesia
list_stopwords = stopwords.words('indonesian')

# ----------------------- add stopword from txt file ------------------------------------
# read txt stopword using pandas
txt_stopword = pd.read_csv("/content/drive/My Drive/Colab-Notebooks/Analisis-Sentimen-Twitter-Terhadap-Pembatalan-Piala-Dunia-U-20-di-Indonesia-Tahun-2023-main/stopwords-id.txt", names= ["stopwords"], header = None)

# convert stopword string to list & append additional stopword
list_stopwords.extend(txt_stopword["stopwords"][0].split(' '))

# convert list to dictionary
list_stopwords = set(list_stopwords)


#remove stopword pada list token
def stopwords_removal(words):
    return [word for word in words if word not in list_stopwords]

df['stopword'] = df['normalisasi'].apply(stopwords_removal)


print(df['stopword'].head())
# Out:
# 0    [anggarkan, rp, triliun, nikuba, karya, anak, ...
# 1    [tolong, pemerintah, perhatianya, nikubakayany...
# 2    [nikubadi, pakai, indonesia, bisnis, bbm, indo...
# 3    [nikubadi, pakai, indonesia, bisnis, bbm, indo...
# 4    [alat, nikuba, kembangkan, pertamina, omsetnya...
# Name: stopword, dtype: object

# %%
list_stopwords
# Out:
# {'&amp',
#  'aaaaa',
#  'aargh',
#  'ada',
#  'adalah',
#  'adanya',
#  'adapun',
#  'agak',
#  'agaknya',
#  'agar',
#  'agv',
#  'ahhh',
#  'ai',
#  'aja',
#  'akan',
#  'akankah',
#  'akhir',
#  'akhiri',
#  'akhirnya',
#  'aku',
#  'akulah',
#  'amat',
#  'amatlah',
#  'amp',
#  'amputmmediumsocialamputmsourcetwitter',
#  'anda',
#  'andalah',
#  'antar',
#  'antara',
#  'antaranya',
#  'apa',
#  'apaan',
#  'apabila',
#  'apakah',
#  'apalagi',
#  'apatah',
#  'artinya',
#  'asal',
#  'asalkan',
#  'atas',
#  'atau',
#  'ataukah',
#  'ataupun',
#  'awal',
#  'awalnya',
#  'awokawokaowk',
#  'bagai',
#  'bagaikan',
#  'bagaimana',
#  'bagaimanakah',
#  'bagaimanapun',
#  'baghowi',
#  'bagi',
#  'bagian',
#  'bahkan',
#  'bahwa',
#  'bahwasanya',
#  'baik',
#  'bakal',
#  'bakalan',
#  'balik',
#  'banyak',
#  'bapak',
#  'baru',
#  'basabasi',
#  'bawah',
#  'beberapa',
#  'begini',
#  'beginian',
#  'beginikah',
#  'beginilah',
#  'begitu',
#  'begitukah',
#  'begitulah',
#  'begitupun',
#  'bekerja',
#  'belakang',
#  'belakangan',
#  'belum',
#  'belumlah',
#  'benar',
#  'benarkah',
#  'benarlah',
#  'berada',
#  'berakhir',
#  'berakhirlah',
#  'berakhirnya',
#  'berapa',
#  'berapakah',
#  'berapalah',
#  'berapapun',
#  'berarti',
#  'berawal',
#  'berbagai',
#  'berdatangan',
#  'beri',
#  'berikan',
#  'berikut',
#  'berikutnya',
#  'berjumlah',
#  'berkali-kali',
#  'berkata',
#  'berkehendak',
#  'berkeinginan',
#  'berkenaan',
#  'berlainan',
#  'berlalu',
#  'berlangsung',
#  'berlebihan',
#  'bermacam',
#  'bermacam-macam',
#  'bermaksud',
#  'bermula',
#  'bersama',
#  'bersama-sama',
#  'bersiap',
#  'bersiap-siap',
#  'bertanya',
#  'bertanya-tanya',
#  'berturut',
#  'berturut-turut',
#  'bertutur',
#  'berujar',
#  'berupa',
#  'besar',
#  'betul',
#  'betulkah',
#  'bgddd',
#  'biar',
#  'biasa',
#  'biasanya',
#  'bikin',
#  'bila',
#  'bilakah',
#  'bilang',
#  'bisa',
#  'bisakah',
#  'bnjiri',
#  'boleh',
#  'bolehkah',
#  'bolehlah',
#  'buahahahahahasampe',
#  'buat',
#  'bukan',
#  'bukankah',
#  'bukanlah',
#  'bukannya',
#  'bulan',
#  'bung',
#  'caiiii',
#  'cara',
#  'caranya',
#  'cc',
#  'chakzzz',
#  'chuaaaakzzzzz',
#  'chuaaakksss',
#  'chuaakkkssss',
#  'chuaks',
#  'chuakss',
#  'chuakzzz',
#  'chukwuemeka',
#  'cieee',
#  'cmiiw',
#  'cni',
#  'cpw',
#  'cuakkks',
#  'cukup',
#  'cukupkah',
#  'cukuplah',
#  'cuma',
#  'd',
#  'dahulu',
#  'dalam',
#  'dan',
#  'dapat',
#  'dari',
#  'daripada',
#  'datang',
#  'dekat',
#  'demi',
#  'demikian',
#  'demikianlah',
#  'dengan',
#  'depan',
#  'dg',
#  'dgn',
#  'di',
#  'dia',
#  'diakhiri',
#  'diakhirinya',
#  'dialah',
#  'diantara',
#  'diantaranya',
#  'diberi',
#  'diberikan',
#  'diberikannya',
#  'dibuat',
#  'dibuatnya',
#  'dicoret',
#  'didapat',
#  'didatangkan',
#  'digunakan',
#  'diibaratkan',
#  'diibaratkannya',
#  'diingat',
#  'diingatkan',
#  'diinginkan',
#  'dijawab',
#  'dijelaskan',
#  'dijelaskannya',
#  'dikarenakan',
#  'dikatakan',
#  'dikatakannya',
#  'dikerjakan',
#  'diketahui',
#  'diketahuinya',
#  'dikira',
#  'dilakukan',
#  'dilalui',
#  'dilihat',
#  'dimaksud',
#  'dimaksudkan',
#  'dimaksudkannya',
#  'dimaksudnya',
#  'diminta',
#  'dimintai',
#  'dimisalkan',
#  'dimulai',
#  'dimulailah',
#  'dimulainya',
#  'dimungkinkan',
#  'dini',
#  'dipastikan',
#  'diperbuat',
#  'diperbuatnya',
#  'dipergunakan',
#  'diperkirakan',
#  'diperlihatkan',
#  'diperlukan',
#  'diperlukannya',
#  'dipersoalkan',
#  'dipertanyakan',
#  'dipunyai',
#  'diri',
#  'dirinya',
#  'disampaikan',
#  'disebut',
#  'disebutkan',
#  'disebutkannya',
#  'disini',
#  'disinilah',
#  'ditambahkan',
#  'ditandaskan',
#  'ditanya',
#  'ditanyai',
#  'ditanyakan',
#  'ditegaskan',
#  'ditujukan',
#  'ditunjuk',
#  'ditunjuki',
#  'ditunjukkan',
#  'ditunjukkannya',
#  'ditunjuknya',
#  'dituturkan',
#  'dituturkannya',
#  'diucapkan',
#  'diucapkannya',
#  'diungkapkan',
#  'dong',
#  'dua',
#  'dulu',
#  'empat',
#  'enggak',
#  'enggaknya',
#  'entah',
#  'entahlah',
#  'fu',
#  'ga',
#  'gak',
#  'gassss',
#  'ge',
#  'getun',
#  'guna',
#  'gunakan',
#  'gung',
#  'gunggg',
#  'guoblokguoblok',
#  'hadehh',
#  'hahahahah',
#  'hahahahahaha',
#  'hahahahahahaha',
#  'hal',
#  'halaaah',
#  'hampir',
#  'hanya',
#  'hanyalah',
#  'hari',
#  'harus',
#  'haruslah',
#  'harusnya',
#  'hca',
#  'hehe',
#  'hehebaru',
#  'heheehee',
#  'hehehe',
#  'hendak',
#  'hendaklah',
#  'hendaknya',
#  'heuheu',
#  'hiiii',
#  'hingga',
#  'hmmmmm',
#  'horeeee',
#  'huhu',
#  'ia',
#  'ialah',
#  'ibarat',
#  'ibaratkan',
#  'ibaratnya',
#  'ibu',
#  'ikntol',
#  'ikut',
#  'ingat',
#  'ingat-ingat',
#  'ingin',
#  'inginkah',
#  'inginkan',
#  'ini',
#  'inikah',
#  'inilah',
#  'itu',
#  'itukah',
#  'itulah',
#  'jadi',
#  'jadilah',
#  'jadinya',
#  'jangan',
#  'jangankan',
#  'janganlah',
#  'jauh',
#  'jawab',
#  'jawaban',
#  'jawabnya',
#  'jd',
#  'jelas',
#  'jelaskan',
#  'jelaslah',
#  'jelasnya',
#  'jgn',
#  'jika',
#  'jikalau',
#  'juga',
#  'jumlah',
#  'jumlahnya',
#  'justru',
#  'kala',
#  'kalau',
#  'kalaulah',
#  'kalaupun',
#  'kalian',
#  'kalo',
#  'kami',
#  'kamilah',
#  'kamu',
#  'kamulah',
#  'kan',
#  'kapan',
#  'kapankah',
#  'kapanpun',
#  'karena',
#  'karenanya',
#  'kasus',
#  'kata',
#  'katakan',
#  'katakanlah',
#  'katanya',
#  'ke',
#  'keadaan',
#  'kebetulan',
#  'kecil',
#  'kedua',
#  'keduanya',
#  'keinginan',
#  'kelamaan',
#  'kelihatan',
#  'kelihatannya',
#  'kelima',
#  'keluar',
#  'kembali',
#  'kemudian',
#  'kemungkinan',
#  'kemungkinannya',
#  'kenapa',
#  'kepada',
#  'kepadanya',
#  'kesampaian',
#  'keseluruhan',
#  'keseluruhannya',
#  'keterlaluan',
#  'ketika',
#  'khususnya',
#  'kini',
#  'kinilah',
#  'kira',
#  'kira-kira',
#  'kiranya',
#  'kita',
#  'kitalah',
#  'klo',
#  'kok',
#  'kqs',
#  'krn',
#  'kurang',
#  'lagi',
#  'lagian',
#  'lah',
#  'lain',
#  'lainnya',
#  'lalu',
#  'lama',
#  'lamanya',
#  'lan',
#  'lanjut',
#  'lanjutnya',
#  'le',
#  'lebih',
#  'lewat',
#  'lima',
#  'loh',
#  'loohh',
#  'luar',
#  'macam',
#  'maka',
#  'makanya',
#  'makin',
#  'malah',
#  'malahan',
#  'mamam',
#  'mampu',
#  'mampukah',
#  'mana',
#  'manakala',
#  'manalagi',
#  'masa',
#  'masalah',
#  'masalahnya',
#  'masih',
#  'masihkah',
#  'masing',
#  'masing-masing',
#  'mau',
#  'maupun',
#  'melainkan',
#  'melakukan',
#  'melalui',
#  'melihat',
#  'melihatnya',
#  'memang',
#  'memastikan',
#  'memberi',
#  'memberikan',
#  'membuat',
#  'memerlukan',
#  'memihak',
#  'meminta',
#  'memintakan',
#  'memisalkan',
#  'memperbuat',
#  'mempergunakan',
#  'memperkirakan',
#  'memperlihatkan',
#  'mempersiapkan',
#  'mempersoalkan',
#  'mempertanyakan',
#  'mempunyai',
#  'memulai',
#  'memungkinkan',
#  'menaiki',
#  'menambahkan',
#  'menandaskan',
#  'menanti',
#  'menanti-nanti',
#  'menantikan',
#  'menanya',
#  'menanyai',
#  'menanyakan',
#  'mendapat',
#  'mendapatkan',
#  'mendatang',
#  'mendatangi',
#  'mendatangkan',
#  'menegaskan',
#  'mengakhiri',
#  'mengapa',
#  'mengatakan',
#  'mengatakannya',
#  'mengenai',
#  'mengerjakan',
#  'mengetahui',
#  'menggunakan',
#  'menghendaki',
#  'mengibaratkan',
#  'mengibaratkannya',
#  'mengingat',
#  'mengingatkan',
#  'menginginkan',
#  'mengira',
#  'mengucapkan',
#  'mengucapkannya',
#  'mengungkapkan',
#  'menjadi',
#  'menjawab',
#  'menjelaskan',
#  'menuju',
#  'menunjuk',
#  'menunjuki',
#  'menunjukkan',
#  'menunjuknya',
#  'menurut',
#  'menuturkan',
#  'menyampaikan',
#  'menyangkut',
#  'menyatakan',
#  'menyebutkan',
#  'menyeluruh',
#  'menyiapkan',
#  'merasa',
#  'mereka',
#  'merekalah',
#  'merupakan',
#  'meski',
#  'meskipun',
#  'meyakini',
#  'meyakinkan',
#  'minta',
#  'mirip',
#  'misal',
#  'misalkan',
#  'misalnya',
#  'mmc',
#  'mula',
#  'mulai',
#  'mulailah',
#  'mulanya',
#  'mungkin',
#  'mungkinkah',
#  'n',
#  'nah',
#  'naik',
#  'namun',
#  'nan',
#  'nanti',
#  'nantinya',
#  'naskleenggg',
#  'nih',
#  'nul',
#  'ny',
#  'nya',
#  'nyaris',
#  'nyatanya',
#  'nyg',
#  'oiya',
#  'okela',
#  'oleh',
#  'olehnya',
#  'pada',
#  'padahal',
#  'padanya',
#  'pak',
#  'paling',
#  'panjang',
#  'pantas',
#  'para',
#  'pasti',
#  'pastilah',
#  'pdip',
#  'pen',
#  'penting',
#  'pentingnya',
#  'per',
#  'percuma',
#  'perlu',
#  'perlukah',
#  'perlunya',
#  'pernah',
#  'persoalan',
#  'pertama',
#  'pertama-tama',
#  'pertanyaan',
#  'pertanyakan',
#  'pi',
#  'pihak',
#  'pihaknya',
#  'pksniidkk',
#  'pppk',
#  'pukul',
#  'pula',
#  'pun',
#  'punya',
#  'quf',
#  'rasa',
#  'rasanya',
#  'rata',
#  'rt',
#  'rupanya',
#  'sa',
#  'saat',
#  'saatnya',
#  'saja',
#  'sajalah',
#  'saling',
#  'sama',
#  'sama-sama',
#  'sambil',
#  'sampai',
#  'sampai-sampai',
#  'sampaikan',
#  'sana',
#  'sanaaaa',
#  'sangat',
#  'sangatlah',
#  'satu',
#  'saya',
#  'sayalah',
#  'sbghostamp',
#  'sdh',
#  'se',
#  'sebab',
#  'sebabnya',
#  'sebagai',
#  'sebagaimana',
#  'sebagainya',
#  'sebagian',
#  'sebaik',
#  'sebaik-baiknya',
#  'sebaiknya',
#  'sebaliknya',
#  'sebanyak',
#  'sebegini',
#  'sebegitu',
#  'sebelum',
#  'sebelumnya',
#  'sebenarnya',
#  'seberapa',
#  'sebesar',
#  'sebetulnya',
#  'sebisanya',
#  'sebuah',
#  'sebut',
#  'sebutlah',
#  'sebutnya',
#  'secara',
#  'secukupnya',
#  'sedang',
#  'sedangkan',
#  'sedemikian',
#  'sedikit',
#  'sedikitnya',
#  'seenaknya',
#  'segala',
#  'segalanya',
#  'segera',
#  'seharusnya',
#  'sehingga',
#  'seingat',
#  'sejak',
#  'sejauh',
#  'sejenak',
#  'sejumlah',
#  'sekadar',
#  'sekadarnya',
#  'sekali',
#  'sekali-kali',
#  'sekalian',
#  'sekaligus',
#  'sekalipun',
#  'sekarang',
#  'sekecil',
#  'seketika',
#  'sekiranya',
#  'sekitar',
#  'sekitarnya',
#  'sekurang-kurangnya',
#  'sekurangnya',
#  'sela',
#  'selagi',
#  'selain',
#  'selaku',
#  'selalu',
#  'selama',
#  'selama-lamanya',
#  'selamanya',
#  'selanjutnya',
#  'seluruh',
#  'seluruhnya',
#  'semacam',
#  'semakin',
#  'semampu',
#  'semampunya',
#  'semasa',
#  'semasih',
#  'semata',
#  'semata-mata',
#  'semaunya',
#  'sementara',
#  'semisal',
#  'semisalnya',
#  'sempat',
#  'semua',
#  'semuanya',
#  'semula',
#  'sendiri',
#  'sendirian',
#  'sendirinya',
#  'seolah',
#  'seolah-olah',
#  'seorang',
#  'sepanjang',
#  'sepantasnya',
#  'sepantasnyalah',
#  'seperlunya',
#  'seperti',
#  'sepertinya',
#  'sepihak',
#  'sering',
#  'seringnya',
#  'serta',
#  'serupa',
#  'sesaat',
#  'sesama',
#  'sesampai',
#  'sesegera',
#  'sesekali',
#  'seseorang',
#  'sesuatu',
#  'sesuatunya',
#  'sesudah',
#  'sesudahnya',
#  'setelah',
#  'setempat',
#  'setengah',
#  'seterusnya',
#  'setiap',
#  'setiba',
#  'setibanya',
#  'setidak-tidaknya',
#  'setidaknya',
#  'setinggi',
#  'seusai',
#  'sewaktu',
#  'si',
#  'siap',
#  'siapa',
#  'siapakah',
#  'siapapun',
#  'sih',
#  'sihhh',
#  'sini',
#  'sinilah',
#  'siregarxix',
#  'soal',
#  'soalnya',
#  'suatu',
#  'sudah',
#  'sudahkah',
#  'sudahlah',
#  'supaya',
#  't',
#  'tadi',
#  'tadinya',
#  'tahu',
#  'tahun',
#  'tak',
#  'tambah',
#  'tambahnya',
#  'tampak',
#  'tampaknya',
#  'tandas',
#  'tandasnya',
#  'tanpa',
#  'tanya',
#  'tanyakan',
#  'tanyanya',
#  'tapi',
#  'tau',
#  'tdk',
#  'tegas',
#  'tegasnya',
#  'telah',
#  'tempat',
#  'tengah',
#  'tentang',
#  'tentu',
#  'tentulah',
#  'tentunya',
#  'tepat',
#  'terakhir',
#  'terasa',
#  'terbanyak',
#  'terdahulu',
#  'terdapat',
#  'terdiri',
#  'terhadap',
#  'terhadapnya',
#  'teringat',
#  'teringat-ingat',
#  'terjadi',
#  'terjadilah',
#  'terjadinya',
#  'terkira',
#  'terlalu',
#  'terlebih',
#  'terlihat',
#  'termasuk',
#  'ternyata',
#  'tersampaikan',
#  'tersebut',
#  'tersebutlah',
#  'tertentu',
#  'tertuju',
#  'terus',
#  'terutama',
#  'tetap',
#  'tetapi',
#  'tiap',
#  'tiba',
#  'tiba-tiba',
#  'tidak',
#  'tidakkah',
#  'tidaklah',
#  'tiga',
#  'tinggi',
#  'tmr',
#  'toh',
#  'tuh',
#  'tunjuk',
#  'turut',
#  'tutur',
#  'tuturnya',
#  'u',
#  'ucap',
#  'ucapnya',
#  'ujar',
#  'ujarnya',
#  'umum',
#  'umumnya',
#  'ungkap',
#  'ungkapnya',
#  'untuk',
#  'usah',
#  'usai',
#  'utk',
#  'waduh',
#  'wah',
#  'wahai',
#  'waktu',
#  'waktunya',
#  'walau',
#  'walaupun',
#  'whehehe',
#  'wkwkk',
#  'wkwkkwkwkw',
#  'wkwkwk',
#  'wkwkwkkwkwk',
#  'wkwkwkwk',
#  'woii',
#  'wong',
#  'wooiii',
#  'wwkwk',
#  'wxp',
#  'xi',
#  'xixiix',
#  'xje',
#  'xxix',
#  'ya',
#  'yah',
#  'yahh',
#  'yaitu',
#  'yakin',
#  'yakni',
#  'yang',
#  'yed',
#  'yg'}

# %%
df
# Out:
#                                                   Text    Label  \
# 0    SAYA SIAP ANGGARKAN RP 40.000 TRILIUN UNTUK NI...  positif
# 1    tolong pemerintah perhatianya ke nikuba,kayany...  positif
# 2    Kalau nikuba,di pakai di Indonesia, tidak ada ...  negatif
# 3    Kalau nikuba,di pakai di Indonesia, tidak ada ...  negatif
# 4    Kalau alat nikuba ini di kembangkan, Pertamina...   netral
# ..                                                 ...      ...
# 549  NIKUBA menyelamatkan kendaraan bensin dari ken...   netral
# 550  15 milyar terlalu kecil, NIKUBA bernilai 1000r...  negatif
# 551  Mengapa pemerintah tidak mau menerima hasil ka...  negatif
# 552  Seharusnya Metro TV tidak hanya nanya ke Aryan...  positif
# 553  Ah, cuma diundang buat presentasi di eropa doa...  positif
#
#                                            CaseFolding  \
# 0    saya siap anggarkan rp 40.000 triliun untuk ni...
# 1    tolong pemerintah perhatianya ke nikuba,kayany...
# 2    kalau nikuba,di pakai di indonesia, tidak ada ...
# 3    kalau nikuba,di pakai di indonesia, tidak ada ...
# 4    kalau alat nikuba ini di kembangkan, pertamina...
# ..                                                 ...
# 549  nikuba menyelamatkan kendaraan bensin dari ken...
# 550  15 milyar terlalu kecil, nikuba bernilai 1000r...
# 551  mengapa pemerintah tidak mau menerima hasil ka...
# 552  seharusnya metro tv tidak hanya nanya ke aryan...
# 553  ah, cuma diundang buat presentasi di eropa doa...
#
#                                              TextClean  \
# 0    saya siap anggarkan rp triliun untuk nikuba ka...
# 1    tolong pemerintah perhatianya ke nikubakayanya...
# 2    kalau nikubadi pakai di indonesia tidak ada la...
# 3    kalau nikubadi pakai di indonesia tidak ada la...
# 4    kalau alat nikuba ini di kembangkan pertamina ...
# ..                                                 ...
# 549  nikuba menyelamatkan kendaraan bensin dari ken...
# 550  milyar terlalu kecil nikuba bernilai ribuan tr...
# 551  mengapa pemerintah tidak mau menerima hasil ka...
# 552  seharusnya metro tv tidak hanya nanya ke aryan...
# 553  ah cuma diundang buat presentasi di eropa doan...
#
#                                                 tokens  \
# 0    [saya, siap, anggarkan, rp, triliun, untuk, ni...
# 1    [tolong, pemerintah, perhatianya, ke, nikubaka...
# 2    [kalau, nikubadi, pakai, di, indonesia, tidak,...
# 3    [kalau, nikubadi, pakai, di, indonesia, tidak,...
# 4    [kalau, alat, nikuba, ini, di, kembangkan, per...
# ..                                                 ...
# 549  [nikuba, menyelamatkan, kendaraan, bensin, dar...
# 550  [milyar, terlalu, kecil, nikuba, bernilai, rib...
# 551  [mengapa, pemerintah, tidak, mau, menerima, ha...
# 552  [seharusnya, metro, tv, tidak, hanya, nanya, k...
# 553  [ah, cuma, diundang, buat, presentasi, di, ero...
#
#                                            normalisasi  \
# 0    [saya, siap, anggarkan, rp, triliun, untuk, ni...
# 1    [tolong, pemerintah, perhatianya, ke, nikubaka...
# 2    [kalau, nikubadi, pakai, di, indonesia, tidak,...
# 3    [kalau, nikubadi, pakai, di, indonesia, tidak,...
# 4    [kalau, alat, nikuba, ini, di, kembangkan, per...
# ..                                                 ...
# 549  [nikuba, menyelamatkan, kendaraan, bensin, dar...
# 550  [milyar, terlalu, kecil, nikuba, bernilai, rib...
# 551  [mengapa, pemerintah, tidak, mau, menerima, ha...
# 552  [seharusnya, metro, tv, tidak, hanya, tanya, k...
# 553  [ah, cuma, diundang, buat, presentasi, di, ero...
#
#                                               stopword
# 0    [anggarkan, rp, triliun, nikuba, karya, anak, ...
# 1    [tolong, pemerintah, perhatianya, nikubakayany...
# 2    [nikubadi, pakai, indonesia, bisnis, bbm, indo...
# 3    [nikubadi, pakai, indonesia, bisnis, bbm, indo...
# 4    [alat, nikuba, kembangkan, pertamina, omsetnya...
# ..                                                 ...
# 549  [nikuba, menyelamatkan, kendaraan, bensin, ken...
# 550  [milyar, nikuba, bernilai, ribuan, triliun, er...
# 551  [pemerintah, menerima, hasil, karya, anak, ban...
# 552  [metro, tv, aryanto, misel, coba, langsung, fe...
# 553  [ah, diundang, presentasi, eropa, doang, macem...
#
# [554 rows x 7 columns]

# %%
df.to_csv('/content/drive/My Drive/Colab-Notebooks/Analisis-Sentimen-Twitter-Terhadap-Pembatalan-Piala-Dunia-U-20-di-Indonesia-Tahun-2023-main/Dataset/nikuba2-label-stopword.csv')

# %% [markdown]
# ## Steaming Data

# %%
pip install sastrawi
# Out:
# Collecting sastrawi
#   Downloading Sastrawi-1.0.1-py2.py3-none-any.whl (209 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.7/209.7 kB 7.1 MB/s eta 0:00:00
# Installing collected packages: sastrawi
# Successfully installed sastrawi-1.0.1

# %%
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory

factory = StemmerFactory()
stemmer = factory.create_stemmer()

def steming(text):
    text = stemmer.stem(text)
    return text

# %%
df1 = pd.read_csv('/content/drive/My Drive/Colab-Notebooks/Analisis-Sentimen-Twitter-Terhadap-Pembatalan-Piala-Dunia-U-20-di-Indonesia-Tahun-2023-main/Dataset/nikuba2-label-stopword.csv')
df1
# Out:
#      Unnamed: 0                                               Text    Label  \
# 0             0  SAYA SIAP ANGGARKAN RP 40.000 TRILIUN UNTUK NI...  positif
# 1             1  tolong pemerintah perhatianya ke nikuba,kayany...  positif
# 2             2  Kalau nikuba,di pakai di Indonesia, tidak ada ...  negatif
# 3             3  Kalau nikuba,di pakai di Indonesia, tidak ada ...  negatif
# 4             4  Kalau alat nikuba ini di kembangkan, Pertamina...   netral
# ..          ...                                                ...      ...
# 549         549  NIKUBA menyelamatkan kendaraan bensin dari ken...   netral
# 550         550  15 milyar terlalu kecil, NIKUBA bernilai 1000r...  negatif
# 551         551  Mengapa pemerintah tidak mau menerima hasil ka...  negatif
# 552         552  Seharusnya Metro TV tidak hanya nanya ke Aryan...  positif
# 553         553  Ah, cuma diundang buat presentasi di eropa doa...  positif
#
#                                            CaseFolding  \
# 0    saya siap anggarkan rp 40.000 triliun untuk ni...
# 1    tolong pemerintah perhatianya ke nikuba,kayany...
# 2    kalau nikuba,di pakai di indonesia, tidak ada ...
# 3    kalau nikuba,di pakai di indonesia, tidak ada ...
# 4    kalau alat nikuba ini di kembangkan, pertamina...
# ..                                                 ...
# 549  nikuba menyelamatkan kendaraan bensin dari ken...
# 550  15 milyar terlalu kecil, nikuba bernilai 1000r...
# 551  mengapa pemerintah tidak mau menerima hasil ka...
# 552  seharusnya metro tv tidak hanya nanya ke aryan...
# 553  ah, cuma diundang buat presentasi di eropa doa...
#
#                                              TextClean  \
# 0    saya siap anggarkan rp triliun untuk nikuba ka...
# 1    tolong pemerintah perhatianya ke nikubakayanya...
# 2    kalau nikubadi pakai di indonesia tidak ada la...
# 3    kalau nikubadi pakai di indonesia tidak ada la...
# 4    kalau alat nikuba ini di kembangkan pertamina ...
# ..                                                 ...
# 549  nikuba menyelamatkan kendaraan bensin dari ken...
# 550  milyar terlalu kecil nikuba bernilai ribuan tr...
# 551  mengapa pemerintah tidak mau menerima hasil ka...
# 552  seharusnya metro tv tidak hanya nanya ke aryan...
# 553  ah cuma diundang buat presentasi di eropa doan...
#
#                                                 tokens  \
# 0    ['saya', 'siap', 'anggarkan', 'rp', 'triliun',...
# 1    ['tolong', 'pemerintah', 'perhatianya', 'ke', ...
# 2    ['kalau', 'nikubadi', 'pakai', 'di', 'indonesi...
# 3    ['kalau', 'nikubadi', 'pakai', 'di', 'indonesi...
# 4    ['kalau', 'alat', 'nikuba', 'ini', 'di', 'kemb...
# ..                                                 ...
# 549  ['nikuba', 'menyelamatkan', 'kendaraan', 'bens...
# 550  ['milyar', 'terlalu', 'kecil', 'nikuba', 'bern...
# 551  ['mengapa', 'pemerintah', 'tidak', 'mau', 'men...
# 552  ['seharusnya', 'metro', 'tv', 'tidak', 'hanya'...
# 553  ['ah', 'cuma', 'diundang', 'buat', 'presentasi...
#
#                                            normalisasi  \
# 0    ['saya', 'siap', 'anggarkan', 'rp', 'triliun',...
# 1    ['tolong', 'pemerintah', 'perhatianya', 'ke', ...
# 2    ['kalau', 'nikubadi', 'pakai', 'di', 'indonesi...
# 3    ['kalau', 'nikubadi', 'pakai', 'di', 'indonesi...
# 4    ['kalau', 'alat', 'nikuba', 'ini', 'di', 'kemb...
# ..                                                 ...
# 549  ['nikuba', 'menyelamatkan', 'kendaraan', 'bens...
# 550  ['milyar', 'terlalu', 'kecil', 'nikuba', 'bern...
# 551  ['mengapa', 'pemerintah', 'tidak', 'mau', 'men...
# 552  ['seharusnya', 'metro', 'tv', 'tidak', 'hanya'...
# 553  ['ah', 'cuma', 'diundang', 'buat', 'presentasi...
#
#                                               stopword
# 0    ['anggarkan', 'rp', 'triliun', 'nikuba', 'kary...
# 1    ['tolong', 'pemerintah', 'perhatianya', 'nikub...
# 2    ['nikubadi', 'pakai', 'indonesia', 'bisnis', '...
# 3    ['nikubadi', 'pakai', 'indonesia', 'bisnis', '...
# 4    ['alat', 'nikuba', 'kembangkan', 'pertamina', ...
# ..                                                 ...
# 549  ['nikuba', 'menyelamatkan', 'kendaraan', 'bens...
# 550  ['milyar', 'nikuba', 'bernilai', 'ribuan', 'tr...
# 551  ['pemerintah', 'menerima', 'hasil', 'karya', '...
# 552  ['metro', 'tv', 'aryanto', 'misel', 'coba', 'l...
# 553  ['ah', 'diundang', 'presentasi', 'eropa', 'doa...
#
# [554 rows x 8 columns]

# %%
df1['Steming'] = df1['stopword'].apply(steming)
df1.head()
# Out:
#    Unnamed: 0                                               Text    Label  \
# 0           0  SAYA SIAP ANGGARKAN RP 40.000 TRILIUN UNTUK NI...  positif
# 1           1  tolong pemerintah perhatianya ke nikuba,kayany...  positif
# 2           2  Kalau nikuba,di pakai di Indonesia, tidak ada ...  negatif
# 3           3  Kalau nikuba,di pakai di Indonesia, tidak ada ...  negatif
# 4           4  Kalau alat nikuba ini di kembangkan, Pertamina...   netral
#
#                                          CaseFolding  \
# 0  saya siap anggarkan rp 40.000 triliun untuk ni...
# 1  tolong pemerintah perhatianya ke nikuba,kayany...
# 2  kalau nikuba,di pakai di indonesia, tidak ada ...
# 3  kalau nikuba,di pakai di indonesia, tidak ada ...
# 4  kalau alat nikuba ini di kembangkan, pertamina...
#
#                                            TextClean  \
# 0  saya siap anggarkan rp triliun untuk nikuba ka...
# 1  tolong pemerintah perhatianya ke nikubakayanya...
# 2  kalau nikubadi pakai di indonesia tidak ada la...
# 3  kalau nikubadi pakai di indonesia tidak ada la...
# 4  kalau alat nikuba ini di kembangkan pertamina ...
#
#                                               tokens  \
# 0  ['saya', 'siap', 'anggarkan', 'rp', 'triliun',...
# 1  ['tolong', 'pemerintah', 'perhatianya', 'ke', ...
# 2  ['kalau', 'nikubadi', 'pakai', 'di', 'indonesi...
# 3  ['kalau', 'nikubadi', 'pakai', 'di', 'indonesi...
# 4  ['kalau', 'alat', 'nikuba', 'ini', 'di', 'kemb...
#
#                                          normalisasi  \
# 0  ['saya', 'siap', 'anggarkan', 'rp', 'triliun',...
# 1  ['tolong', 'pemerintah', 'perhatianya', 'ke', ...
# 2  ['kalau', 'nikubadi', 'pakai', 'di', 'indonesi...
# 3  ['kalau', 'nikubadi', 'pakai', 'di', 'indonesi...
# 4  ['kalau', 'alat', 'nikuba', 'ini', 'di', 'kemb...
#
#                                             stopword  \
# 0  ['anggarkan', 'rp', 'triliun', 'nikuba', 'kary...
# 1  ['tolong', 'pemerintah', 'perhatianya', 'nikub...
# 2  ['nikubadi', 'pakai', 'indonesia', 'bisnis', '...
# 3  ['nikubadi', 'pakai', 'indonesia', 'bisnis', '...
# 4  ['alat', 'nikuba', 'kembangkan', 'pertamina', ...
#
#                                              Steming
# 0  anggar rp triliun nikuba karya anak bangsa ins...
# 1  tolong perintah perhatianya nikubakayanya bp a...
# 2      nikubadi pakai indonesia bisnis bbm indonesia
# 3      nikubadi pakai indonesia bisnis bbm indonesia
# 4         alat nikuba kembang pertamina omset anjlok

# %%
keep_col = ['Steming','Label']
df1 = df1[keep_col]
df1.to_csv('/content/drive/My Drive/Colab-Notebooks/Analisis-Sentimen-Twitter-Terhadap-Pembatalan-Piala-Dunia-U-20-di-Indonesia-Tahun-2023-main/Dataset/nikuba2-label-steming.csv')

# %% [markdown]
# ## Menghapus Data set Duplicate

# %%
# df.drop_duplicates(subset='Steming', keep = 'first', inplace = True)
# # df1

# %%
# pd.value_counts(df1['Label'])
